# %%
lotto_data = []
with open('lott.CSV') as file:
    for line in file:
        lotto_data.append(line[:-1].split(','))
print(lotto_data)
int(lotto_data[0][-1])
# Out:
# [['5', '17', '26', '27', '35', '38', '1'], ['21', '26', '30', '32', '33', '35', '44'], ['6', '12', '31', '35', '38', '43', '17'], ['3', '5', '13', '20', '21', '37', '17'], ['6', '12', '17', '21', '32', '39', '30'], ['2', '20', '33', '40', '42', '44', '32'], ['7', '16', '25', '29', '35', '36', '28'], ['6', '14', '15', '19', '21', '41', '37'], ['12', '17', '20', '26', '28', '36', '4'], ['3', '5', '12', '22', '26', '31', '19'], ['5', '14', '15', '23', '34', '43', '4'], ['6', '7', '9', '11', '17', '18', '45'], ['8', '16', '26', '29', '31', '36', '11'], ['2', '3', '6', '19', '36', '39', '26'], ['7', '16', '24', '27', '37', '44', '2'], ['2', '14', '15', '22', '27', '33', '31'], ['2', '5', '22', '32', '34', '45', '39'], ['9', '14', '34', '35', '41', '42', '2'], ['26', '31', '32', '33', '38', '40', '11'], ['3', '11', '15', '20', '35', '44', '10'], ['1', '6', '12', '19', '36', '42', '28'], ['6', '7', '22', '32', '35', '36', '19'], ['2', '5', '11', '17', '24', '29', '9'], ['12', '30', '32', '3
# ...

# %% [markdown]
# # 1.전체 회차를 통틀어 빈도수 (mode): 숫자별 카운트 (몇번이나 나왔나?)
# # 2. 회차별 - 평균값, 표준 편차

# %%
lista = []
for i in lotto_data:
    for e in i[:-1]:
        lista.append(int(e))
seta = set(lista)

for i in seta:
    print (i, lista.count(i))
# Out:
# 1 146
# 2 141
# 3 140
# 4 140
# 5 140
# 6 134
# 7 138
# 8 136
# 9 113
# 10 140
# 11 143
# 12 155
# 13 149
# 14 150
# 15 144
# 16 138
# 17 152
# 18 155
# 19 138
# 20 147
# 21 142
# 22 121
# 23 125
# 24 139
# 25 134
# 26 142
# 27 152
# 28 126
# 29 133
# 30 125
# 31 142
# 32 121
# 33 146
# 34 161
# 35 137
# 36 142
# 37 146
# 38 139
# 39 150
# 40 145
# 41 131
# 42 138
# 43 148
# 44 141
# 45 147

# %%
mean_num = 0

for i, e in enumerate(lotto_data):
    for x in e :
          mean_num = int(sum(e)/ len(e))
        
    print(i + 1,'회차 평균: ', mean_num)
# Out:
# 1 회차 평균:  21
# 2 회차 평균:  31
# 3 회차 평균:  26
# 4 회차 평균:  16
# 5 회차 평균:  22
# 6 회차 평균:  30
# 7 회차 평균:  25
# 8 회차 평균:  21
# 9 회차 평균:  20
# 10 회차 평균:  16
# 11 회차 평균:  19
# 12 회차 평균:  16
# 13 회차 평균:  22
# 14 회차 평균:  18
# 15 회차 평균:  22
# 16 회차 평균:  20
# 17 회차 평균:  25
# 18 회차 평균:  25
# 19 회차 평균:  30
# 20 회차 평균:  19
# 21 회차 평균:  20
# 22 회차 평균:  22
# 23 회차 평균:  13
# 24 회차 평균:  30
# 25 회차 평균:  16
# 26 회차 평균:  25
# 27 회차 평균:  24
# 28 회차 평균:  18
# 29 회차 평균:  23
# 30 회차 평균:  21
# 31 회차 평균:  23
# 32 회차 평균:  22
# 33 회차 평균:  28
# 34 회차 평균:  16
# 35 회차 평균:  26
# 36 회차 평균:  24
# 37 회차 평균:  32
# 38 회차 평균:  31
# 39 회차 평균:  17
# 40 회차 평균:  30
# 41 회차 평균:  19
# 42 회차 평균:  23
# 43 회차 평균:  19
# 44 회차 평균:  29
# 45 회차 평균:  28
# 46 회차 평균:  20
# 47 회차 평균:  20
# 48 회차 평균:  19
# 49 회차 평균:  27
# 50 회차 평균:  27
# 51 회차 평균:  29
# 52 회차 평균:  17
# 53 회차 평균:  23
# 54 회차 평균:  15
# 55 회차 평균:  28
# 56 회차 평균:  18
# 57 회차 평균:  22
# 58 회차 평균:  18
# 59 회차 평균:  18
# 60 회차 평균:  23
# 61 회차 평균:  29
# 62 회차 평균:  28
# 63 회차 평균:  22
# ...

# %%
for i, e in enumerate(lotto_data):
    for x in e :
        mean_num = int(sum(e)/ len(e))
    n = len(e)
    d = [y - mean_num for y in e] 
    stdev = math.sqrt(sum([z * z for z in d])/(n - 1))    
    print(i,'회차별 표준편차',stdev)
# Out:
# 0 회차별 표준편차 14.247806848775006
# 1 회차별 표준편차 7.2571803523590805
# 2 회차별 표준편차 14.236104336041748
# 3 회차별 표준편차 11.416362526362473
# 4 회차별 표준편차 11.796892246124258
# 5 회차별 표준편차 14.927603067248718
# 6 회차별 표준편차 10.41633332799983
# 7 회차별 표준편차 12.7148207485071
# 8 회차별 표준편차 10.684880283216405
# 9 회차별 표준편차 10.614455552060438
# 10 회차별 표준편차 14.600228308717185
# 11 회차별 표준편차 13.546217184144066
# 12 회차별 표준편차 10.762589527308627
# 13 회차별 표준편차 15.572411502397436
# 14 회차별 표준편차 15.269795894728476
# 15 회차별 표준편차 11.015141094572204
# 16 회차별 표준편차 16.65332799572906
# 17 회차별 표준편차 16.492422502470642
# 18 회차별 표준편차 9.617692030835672
# 19 회차별 표준편차 14.713938969562161
# 20 회차별 표준편차 15.416441439796236
# 21 회차별 표준편차 12.616127245183709
# 22 회차별 표준편차 9.983319421247959
# 23 회차별 표준편차 10.124228365658293
# 24 회차별 표준편차 10.336021155809101
# 25 회차별 표준편차 14.730919862656235
# 26 회차별 표준편차 13.711309200802088
# 27 회차별 표준편차 10.808946911393974
# 28 회차별 표준편차 13.32916601542147
# 29 회차별 표준편차 8.94427190999916
# ...
