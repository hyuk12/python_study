# %%
data_list1 = []
with open('%EC%A0%84%EA%B5%AD%EA%B1%B4%EA%B0%95%EC%A6%9D%EC%A7%84%EC%84%BC%ED%84%B0%ED%91%9C%EC%A4%80%EB%8D%B0%EC%9D%B4%ED%84%B0.csv', encoding = 'cp949') as file:
    for line in file:
        data_list1.append(line.split(','))

# %%
data_list1 = data_list1[1:]

# %%
address_list = []
for i in data_list1:
    address = i[2].lstrip('""')

    flag = (len(i[2]) == 0)
    if flag == False:
        address_list.append(address.split())
    
address_list = address_list[3:]
#     address_list = address.split()
    
#     address_list
#     print(address_list)

# %%
print(address_list)
# Out:
# [['인천광역시', '연수구', '함박뫼로', '13'], ['경상북도', '청송군', '청송읍', '의료원길', '19'], ['인천광역시', '중구', '참외전로72번길', '21'], ['경상남도', '의령군', '의령읍', '의병로8길', '16'], ['강원도', '고성군', '간성읍', '수성로', '30'], ['강원도', '강릉시', '성덕포남로', '80-22'], ['충청북도', '영동군', '영동읍', '반곡동길', '7'], ['부산광역시', '서구', '구덕로', '127'], ['광주광역시', '광산구', '무진대로', '246'], ['경상북도', '문경시', '점촌1길', '13'], ['경상북도', '경주시', '양정로', '300'], ['강원도', '영월군', '영월읍', '하송로', '46-43'], ['경상남도', '김해시', '주촌면', '주선로', '29-1'], ['경기도', '포천시', '포천로', '1612'], ['부산광역시', '남구', '유엔평화로4번길', '61'], ['부산광역시', '강서구', '공항진입로', '8'], ['경상북도', '상주시', '경상대로', '3023'], ['부산광역시', '기장군', '정관읍', '용수로', '11'], ['경기도', '화성시', '향남읍', '발안만세길', '10'], ['전라북도', '무주군', '무주읍', '한풍루로', '413'], ['경기도', '하남시', '미사강변대로', '200'], ['부산광역시', '동래구', '명륜로187번길', '56'], ['서울특별시', '성동구', '행당로', '12'], ['경북', '칠곡군', '왜관읍', '관문로1길', '30'], ['광주광역시', '광산구', '상무대로', '239-1'], ['광주광역시', '광산구', '상무대로', '287'], ['전라남도', '여수시', '시청서4길47(학동)'], ['경기도', '의정부시', '범골로', '131'], ['경상북도', '김천시', '체육공원길', '21'], ['충청북도', '충주시', '사직산21길34'], ['서울특별시', '구로구', '새말로60'], ['경상남도', '통영시', '안개4길', '108'], ['경상남도', '창녕군', '창녕읍', '우포2로', '1189-35'], ['광주광역시', '북구', '북문대로', '43'], ['경상남도', '고성군', '고성읍', '남포로', '79번길', '103-3'], ['부산광역시', '해운대구', '반송로', '853'], ['충청남도', '부여군', '부여읍', '성왕로', '205'], ['충청남도', '부여군', '부여읍', '청마로', '61'], ['충청남도', '부여군', '부여읍', '성왕로', '205'], ['제주특별자치도', '서귀포시', '남원읍', '태위로', '527'], ['제주특별자치도', '서귀포시', '성산읍', '고성오조로', '42'], ['제주특별자치도', '서귀포시', '표선면', '표선중앙로', '17'], ['제주특별자치도', '서귀포시', '중앙로101번길', '52(서홍동)'], ['제주특별자치도', '서귀포시', '중앙로101번길', '52(서홍동)'], ['제주특별자치도', '서귀포시', '중앙로101번길', '52(서홍동)'], ['제주특별자치도', '서귀포시', '대정읍', '최남단해안로15번길', '12'], ['제주특별자치도', '서귀포시', '안덕면', '화순중앙로12번길', '30-9'], ['전라북도', '남원시', '요천로', '1285'], ['경상북도', '청송군', '안덕면', '안덕로', '80'], ['울산광역시', '남구', '삼산중로', '132'], ['울산광역시', '남구', '대학로', '147번길', '41-26'], ['경기도', '성남시', '수정구', '수정로', '218'], ['경기도', '성남시', '중원구', '금상로', '137'], ['경기도', '성남시', '분당구', '양현로', '306'], ['대구광역시', '달성군', '옥포읍', '비슬로458길', '6-2'], ['전라남도', '곡성군', '곡성읍', '곡성로', '854'], ['충청남도', '태안군', '태안읍', '서해로', '1952-16'], ['부산광역시', '영도구', '동삼북로', '3(동삼동)'], ['경상남도', '사천시', '용현면', '시청로', '77-1'], ['대전광역시', '유성구', '박산로', '177'], ['대구광역시', '서구', '서대구로7길', '46'], ['대구광역시', '북구', '성북로', '43'], ['경상남도', '진주시', '문산읍', '월아산로', '983'], ['울산광역시', '북구', '산업로', '1018'], ['경기도', '부천시', '성오로', '172'], ['경기도', '오산시', '경기동로', '59'], ['서울특별시', '종로구', '성균관로15길', '10'], ['서울특별시', '종로구', '성균관로1길', '6-3'], ['전라북도', '익산시', '무왕로', '975'], ['전라남도', '나주시', '노안면', '노안삼도로', '507-22'], ['전라남도', '나주시', '다도면', '다도로', '287-22'], ['광주광역시', '동구', '서남로', '14'], ['광주광역시', '동구', '구성로', '190'], ['경상북도', '경산시', '남매로', '158'], ['충청북도', '단양군', '단양읍', '별곡1로', '17'], ['충청남도', '천안시', '서북구', '서부8길', '29'], ['충청북도', '옥천군', '옥천읍', '삼양로8길', '10'], ['대구광역시', '중구', '태평로', '45'], ['전라남도', '구례군', '구례읍', '동편제길', '30'], ['대구광역시', '수성구', '수성로', '213'], ['대구광역시', '수성구', '욱수천로', '99'], ['경상북도', '영주시', '영주로159번길', '73'], ['광주광역시', '광산구', '우산로', '17'], ['광주광역시', '동구', '서남로', '14'], ['광주광역시', '동구', '지원로', '31-9'], ['서울특별시', '강북구', '삼양로19길', '154'], ['서울특별시', '노원구', '노해로', '455'], ['경상남도', '남해군', '남해읍', '선소로', '6'], ['서울특별시', '강남구', '밤고개로1길', '52'], ['서울특별시', '강남구', '밤고개로', '286'], ['인천광역시', '계양구', '봉오대로543번길', '21'], ['서울특별시', '강서구', '공항대로', '561'], ['경기도', '남양주시', '호평로68번길', '21'], ['경기도', '남양주시', '화도읍', '비룡로', '59'], ['경기도', '군포시', '군포로', '221'], ['서울특별시', '중랑구', '면목로', '238'], ['강원도', '인제군', '인제읍', '인제로', '140번길', '34'], ['울산광역시', '중구', '외솔큰길', '225'], ['경기도', '이천시', '이섭대천로', '1119(증일동)', '2층'], ['경상남도', '산청군', '산청읍', '중앙로', '97'], ['경기도', '광명시', '광명로', '942-1'], ['경기도', '고양시', '덕양구', '혜음로', '19-11'], ['경상남도', '거창군', '거창읍', '거함대로', '3079'], ['전라남도', '영광군', '영광읍', '신남로4길17'], ['전라남도', '광양시', '광양읍', '인덕로', '1100'], ['전라남도', '광양시', '광양읍', '인덕로', '1100'], ['전라남도', '광양시', '광양읍', '호북길', '13-3'], ['경상북도', '청도군', '화양읍', '청화로', '79-11'], ['서울특별시', '중구', '서소문로6길', '16'], ['대전광역시', '서구', '만년로', '74'], ['대전광역시', '서구', '구봉산북로', '300'], ['경기도', '가평군', '가평읍', '가화 ...

# %%
si_address = []
for i in address_list:
    s = i[0]
    si_address.append(s)
    
# si_address.index('경북')
si_address[20] = '경상북도'

# %%
set1 = set(si_address)

for i in set1:
    print(i, si_address.count(i))
# Out:
# 경상남도 20
# 울산광역시 7
# 전라남도 20
# 제주특별자치도 10
# 전라북도 14
# 세종특별자치시 1
# 부산광역시 18
# 경기도 65
# 대구광역시 8
# 대전광역시 10
# 광주광역시 11
# 충청남도 16
# 충청북도 12
# 강원도 16
# 경상북도 21
# 서울특별시 26
# 인천광역시 13
