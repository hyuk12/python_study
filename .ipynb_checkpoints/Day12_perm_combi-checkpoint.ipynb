# %% [markdown]
# # 192.168.2.101:8000
#
# def fact(n):
#     ret = 1
#     while n>1:
#         ret *= n
#         n -= 1
#     return ret
#
# def fact_r(n):
#     if n==2:
#         return n
#     return fact_r(n-1)*n
#
# def perm_f(n, r):
#     return fact(n)/fact(n-r)
#
# def combi_f(n, r):
#     return fact(n)/(fact(n-r)*fact(r))
#
# def count_with_replacement_order(pool, sel_count):  # all
#     if sel_count == 1:
#         return len(pool), [[x] for x in pool]
#     a, b = count_with_replacement_order(pool, sel_count-1)
#     r = []
#     for x in pool:
#         for b_i in b:
#             r.append(b_i+[x])
#     return len(r), r
#
# def perm_pool(pool, r):
#     if r == 1:
#         return len(pool), [[x] for x in pool]
#     ret = []
#     for x in pool:
#         pool_copy = [y for y in pool]
#         pool_copy.remove(x)
#         a, b = perm_pool(pool_copy, r-1)
#         for b_i in b:
#             ret.append(b_i+[x])
#     return len(ret), ret
#
# def combi_pool(pool, r):
#     a , b = perm_pool(pool, r)
#     r = []
#     for b_i in b:
#         r.append(set(b_i))
#     f = []
#     for r_i in r:
#         if r_i not in f:
#             f.append(r_i)
#     return len(f), f

# %% [markdown]
# ## 주사위를 세번던져 나올수 있는 모든 경우의 수 (with replacement)
#
# - 첫번째 : 6가지
# - 두번째 : 6가지
# - 세번째 : 6가지
#
# > 총 6 * 6 * 6
#
# ## 1에서 부터 6까지 숫자가 적힌 공이 든 박스에서 2개의 공을 꺼낼 때 나올수 있는 모든 경우의 수(without replacement)
#
# - 첫번째 : 6가지
# - 두번째 : 5가지
#
#
# > 총 6 * 5
#
# ```python
# # permutation (순열) : (a, b, c) (b, c, a) 다른 것이다. 순서의 개념이 있음
#
#
# n = 6
# r = 2
#
# # n! / (n - r)!
#
# ```
#
# ## 1에서 부터 6까지 숫자가 적힌 공이 든 박스에서 2개의 공을 꺼냈을 때
# ## '다른 구성'으로 나올수 있는 모든 경우의 수(without replacement)
#
# - pernutation(순열) 에서 구성이 같은 것을 제외 -> 조합
#
#
# ```python
#
# # combination (조합) : (a, b, c) (b, c, a) 같다. 순서의 개념이 없음
#
# n = 6
# r = 2
#
# # (n! / (n - r)!) / r!
#
# ```
#
#
#
# ## 1에서 부터 6까지 숫자가 적힌 공이 든 박스에서 3개의 공을 꺼내면서 꺼낸 공을 다시 집어넣고, 섞어서 뽑았을 때 나올수 있는 모든 경우의 수
#
# - 첫번째 : 6가지
# - 두번째 : 6가지
# - 세번째 : 6가지
#
# > 총 6 * 6 * 6

# %% [markdown]
# ## 팩토리얼 을 만드는 함수
#
# -  재귀 함수로 만든다 ( 자기 자신을 부르는 (사용하는) 함수)
# -  탈출조건이 중요하다 ( 그렇지 않으면 무한반복을 돈다)

# %%
import numpy as np
# 재귀 함수
def fact_r(n):
    if n ==2:
        return n
    return fact_r(n-1) * n

# 일반적인 팩터리얼

def fact(n):
    ret = 1
    while n > 1:
        ret *= n
        n -= 1
    return ret    

def fact_np(n):
    return np.arange(2, n + 1).prod()
#     return np.multiyply.reduce(np.arange(2, n+1))

# %% [markdown]
# ## 순열구하기

# %%
def perm(n, r):
    return fact_r(n) / fact_r(n - r)

def combi(n, r):
    return perm(n, r) / fact_r(r)

def count_with_replacement_order(pool, sel_count):  # all
    if sel_count == 1:
        return len(pool), [[x] for x in pool]
    a, b = count_with_replacement_order(pool, sel_count-1)
    r = []
    for x in pool:
        for b_i in b:
            r.append(b_i+[x])
    return len(r), r    

def perm_pool(pool, r):
    if r == 1:
        return len(pool), [[x] for x in pool]
    ret = []
    for x in pool:
        pool_copy = [y for y in pool]
        pool_copy.remove(x)
        a, b = perm_pool(pool_copy, r-1)
        for b_i in b:
            ret.append(b_i+[x])
    return len(ret), ret

def combi_pool(pool, r):
    a , b = perm_pool(pool, r)
    r = []
    for b_i in b:
        r.append(set(b_i))
    f = []
    for r_i in r:
        f.append(r_i)
        while r_i in r:
            r.remove(r_i)
    if r:
        f.append(r[0])
    return len(f), f

assert perm(6, 2) == 30.0
assert perm(6, 3) == 120.0
assert fact_np(6) == fact_r(6)
assert combi(6, 2) == 15.0

# %%
# count_with_replacement_order(list('abcdef'), 3)
# perm_pool(list('abcdef'), 3)
combi_pool(list('abcdef'), 3)
# Out:
# (19,
#  [{'a', 'b', 'c'},
#   {'a', 'b', 'e'},
#   {'a', 'c', 'd'},
#   {'a', 'c', 'f'},
#   {'a', 'd', 'e'},
#   {'a', 'c', 'e'},
#   {'a', 'd', 'f'},
#   {'a', 'b', 'f'},
#   {'a', 'b', 'd'},
#   {'b', 'd', 'e'},
#   {'b', 'd', 'f'},
#   {'b', 'c', 'e'},
#   {'c', 'd', 'f'},
#   {'c', 'e', 'f'},
#   {'b', 'c', 'd'},
#   {'b', 'e', 'f'},
#   {'a', 'e', 'f'},
#   {'d', 'e', 'f'},
#   {'b', 'c', 'f'}])
