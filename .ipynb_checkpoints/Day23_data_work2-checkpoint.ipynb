# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd_data = pd.read_csv('데이터산업기술.csv', encoding='cp949')
pd_data.drop('기술등급별(1)', axis = 1, inplace = True)

# %%
pd_data['데이터직무별(1)']
# Out:
# 0       데이터 아키텍트
# 1       데이터 아키텍트
# 2       데이터 아키텍트
# 3       데이터 아키텍트
# 4       데이터 아키텍트
# 5       데이터 아키텍트
# 6        데이터 개발자
# 7        데이터 개발자
# 8        데이터 개발자
# 9        데이터 개발자
# 10       데이터 개발자
# 11       데이터 개발자
# 12      데이터 엔지니어
# 13      데이터 엔지니어
# 14      데이터 엔지니어
# 15      데이터 엔지니어
# 16      데이터 엔지니어
# 17      데이터 엔지니어
# 18       데이터 분석가
# 19       데이터 분석가
# 20       데이터 분석가
# 21       데이터 분석가
# 22       데이터 분석가
# 23       데이터 분석가
# 24    데이터베이스 관리자
# 25    데이터베이스 관리자
# 26    데이터베이스 관리자
# 27    데이터베이스 관리자
# 28    데이터베이스 관리자
# 29    데이터베이스 관리자
# 30       데이터 과학자
# 31       데이터 과학자
# 32       데이터 과학자
# 33       데이터 과학자
# 34       데이터 과학자
# 35       데이터 과학자
# 36      데이터 컨설턴트
# 37      데이터 컨설턴트
# 38      데이터 컨설턴트
# 39      데이터 컨설턴트
# 40      데이터 컨설턴트
# 41      데이터 컨설턴트
# 42       데이터 기획자
# 43       데이터 기획자
# 44       데이터 기획자
# 45       데이터 기획자
# 46       데이터 기획자
# 47       데이터 기획자
# Name: 데이터직무별(1), dtype: object

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 10))
ax = ax.flatten()

for i, column in enumerate(pd_data.columns[1:]):
    ax[i].plot(pd_data['시점'], pd_data['데이터직무별(1)'])
    ax[i].set_title(column)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 53581 (\N{HANGUL SYLLABLE TEG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 50644 (\N{HANGUL SYLLABLE EN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 48288 (\N{HANGUL SYLLABLE BE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 52968 (\N{HANGUL SYLLABLE KEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 53556 (\N{HANGUL SYLLABLE TEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 54925 (\N{HANGUL SYLLABLE HOEG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49556 (\N{HANGUL SYLLABLE SOL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 47144 (\N{HANGUL SYLLABLE RYEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/4105210948.py:8: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.tight_layout()
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53581 (\N{HANGUL SYLLABLE TEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50644 (\N{HANGUL SYLLABLE EN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48288 (\N{HANGUL SYLLABLE BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52968 (\N{HANGUL SYLLABLE KEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53556 (\N{HANGUL SYLLABLE TEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54925 (\N{HANGUL SYLLABLE HOEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49556 (\N{HANGUL SYLLABLE SOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47144 (\N{HANGUL SYLLABLE RYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_architect1 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 아키텍트']
df_architect2 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 엔지니어']
df_architect3 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 개발자']
df_architect4 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 분석가']
df_architect5 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터베이스 관리자']
df_architect6 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 과학자']
df_architect7 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 컨설턴트']
df_architect8 = pd_data.loc[pd_data['데이터직무별(1)'] == '데이터 기획자']

_, ax = plt.subplots(2, 4, figsize=(20, 10))
ax = ax.flatten()

for i, column in enumerate(df_architect1.columns[2:]):
    ax[i].plot(df_architect1['시점'], df_architect1[column])
    ax[i].set_title(column)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49556 (\N{HANGUL SYLLABLE SOL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 52968 (\N{HANGUL SYLLABLE KEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 47144 (\N{HANGUL SYLLABLE RYEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/br/8bbtv7t175s4k3b2shs9n46m0000gn/T/ipykernel_3699/2228908813.py:10: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.tight_layout()
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49556 (\N{HANGUL SYLLABLE SOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52968 (\N{HANGUL SYLLABLE KEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47144 (\N{HANGUL SYLLABLE RYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
_, ax = plt.subplots()
ax.plot(df_architect['시점'], df_architect.iloc[:, 3])
ax.plot(df_architect['시점'], df_architect.iloc[:, 4])

# %%
from matplotlib import font_manager, rc

font_fname = 'D2Coding-Ver1.3.2-20180524-all.ttc'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

grouped = pd_data.groupby('데이터직무별(1)')

fig, ax = plt.subplots(2, 4, figsize=(20, 10))
ax = ax.flatten()

for i, (name, group) in enumerate(grouped):
    for j, column in enumerate(group.columns[2:]):
        ax[j].plot(group['시점'], group[column], label=name)
        ax[j].set_title(column)

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
